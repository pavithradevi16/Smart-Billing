# %%
# All module imports
import tensorflow as tf
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dropout,Flatten,Dense
from sklearn.model_selection import train_test_split

# %%
# Initialize data set directory name and allowed image file extensions
dataSetDir = "Data Set"
imageExt = ["jpg","png","jpeg","webp"]
newImageSize = (256,256)

# %%
# Prevent tensorflow from using all GPU resources
gpus = tf.config.experimental.list_physical_devices("GPU")
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu,True)

# Cosmetic Statement. Only changes how prints are displayed
np.set_printoptions(linewidth=200)

# %%
# Reads all images from all directories within the dataset directory, and puts them into features and labels
classLabel = 0
features = []
labels = []
for imageDir in os.listdir(dataSetDir):
    for image in os.listdir(os.path.join(dataSetDir,imageDir)):
        if image.split(".")[-1] in imageExt:
            imagePath = os.path.join(dataSetDir,imageDir,image)
            image = cv2.cvtColor(cv2.imread(imagePath),cv2.COLOR_BGR2RGB)
            image = cv2.resize(image,newImageSize)
            #print(image)
            features.append(image)
            labels.append(classLabel)
            #plt.imshow(image)
            #plt.show()
    classLabel+=1

# Shuffle the features and labels together, unpack them, then normalize the feature sizes from 0-255 to 0-1 pixels
#dataSet = list(zip(features,labels))
#np.random.shuffle(dataSet)
#features, labels = zip(*dataSet)
features = np.array(features)
labels = np.array(labels)
features = features / 255

# %%
trainingImages, testImages, trainingLabels, testLabels = train_test_split(
    features, labels, test_size=0.3, random_state = 42)
#i = 25
#plt.title(trainingLabels[i])
#plt.imshow(trainingImages[i])

# %%
model = Sequential()
# Input Layer
model.add(Conv2D(64, (3,3), input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(2,2))
# Hidden Layers
model.add(Conv2D(64, (3,3), activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3,3), activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(Dense(64, activation="relu"))
# Output Layer
model.add(Dense(6,activation = "softmax"))
# Compile and summarize the model
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_46 (Conv2D)          (None, 254, 254, 64)      1792
#
#  max_pooling2d_46 (MaxPooli  (None, 127, 127, 64)      0
#  ng2D)
#
#  conv2d_47 (Conv2D)          (None, 125, 125, 64)      36928
#
#  max_pooling2d_47 (MaxPooli  (None, 62, 62, 64)        0
#  ng2D)
#
#  conv2d_48 (Conv2D)          (None, 60, 60, 64)        36928
#
#  max_pooling2d_48 (MaxPooli  (None, 30, 30, 64)        0
#  ng2D)
#
#  flatten_19 (Flatten)        (None, 57600)             0
#
#  dense_38 (Dense)            (None, 512)               29491712
#
#  dense_39 (Dense)            (None, 64)                32832
#
#  dense_40 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 29600582 (112.92 MB)
# Trainable params: 29600582 (112.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(trainingImages,trainingLabels,epochs=7)
model.evaluate(testImages,testLabels)
# Out:
# Epoch 1/7
# 3/3 [==============================] - 3s 843ms/step - loss: 1.0214 - accuracy: 0.7125
# Epoch 2/7
# 3/3 [==============================] - 3s 853ms/step - loss: 0.8407 - accuracy: 0.7125
# Epoch 3/7
# 3/3 [==============================] - 3s 847ms/step - loss: 0.6426 - accuracy: 0.8000
# Epoch 4/7
# 3/3 [==============================] - 3s 839ms/step - loss: 0.3932 - accuracy: 0.8875
# Epoch 5/7
# 3/3 [==============================] - 3s 849ms/step - loss: 0.3605 - accuracy: 0.8875
# Epoch 6/7
# 3/3 [==============================] - 3s 869ms/step - loss: 0.3344 - accuracy: 0.8875
# Epoch 7/7
# 3/3 [==============================] - 3s 848ms/step - loss: 0.1908 - accuracy: 0.9625
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6000 - accuracy: 0.7143
# [0.600018322467804, 0.7142857313156128]

# %%
results = np.array(model.predict(testImages))
plt.imshow(testImages[5])
for i in range(len(testLabels)):
    print(testLabels[i],":",results[i],":",max(results[i]))
# Out:
# 2/2 [==============================] - 0s 31ms/step
# 4 : [8.3759247e-08 6.4129063e-06 1.9368895e-06 1.2838580e-03 9.9870694e-01 7.3649505e-07] : 0.99870694
# 0 : [8.2755524e-01 1.1332636e-01 5.8478255e-02 5.3971022e-04 9.6313861e-06 9.0681184e-05] : 0.82755524
# 2 : [0.00874381 0.00043072 0.36160854 0.09995658 0.15889978 0.37036055] : 0.37036055
# 3 : [0.01373996 0.00337528 0.03800714 0.5727862  0.00798789 0.3641035 ] : 0.5727862
# 0 : [7.19409466e-01 6.45760521e-02 2.14585155e-01 1.12827390e-03 1.91802974e-04 1.09115565e-04] : 0.71940947
# 2 : [0.11516614 0.00180883 0.4269797  0.43109807 0.0130072  0.01194006] : 0.43109807
# 3 : [0.00306736 0.0013063  0.00504354 0.95047766 0.00328025 0.03682482] : 0.95047766
# 3 : [0.01538437 0.00475404 0.02570885 0.728769   0.0102088  0.21517491] : 0.728769
# 2 : [8.5625339e-01 9.3079085e-05 1.3905616e-01 3.0524086e-03 3.0597797e-04 1.2389669e-03] : 0.8562534
# 0 : [7.1930534e-01 8.7609095e-04 2.7879286e-01 8.0561708e-04 8.5095438e-05 1.3505110e-04] : 0.71930534
# 5 : [0.0055792  0.00183118 0.0118141  0.653288   0.00853247 0.31895506] : 0.653288
# 2 : [9.8299445e-08 3.4647167e-11 5.0619513e-01 1.2787342e-05 4.7482118e-01 1.8970806e-02] : 0.5061951
# 4 : [4.2479527e-08 1.8651320e-09 3.8914031e-06 1.5066343e-04 9.9983180e-01 1.3601645e-05] : 0.9998318
# 5 : [0.00304761 0.00112132 0.01449487 0.8453645  0.02258926 0.11338244] : 0.8453645
# 1 : [8.6022128e-06 9.9993062e-01 5.7848145e-05 2.6069961e-06 4.7049493e-09 2.8025147e-07] : 0.9999306
# 0 : [5.8536774e-01 2.2165904e-04 2.1442904e-01 9.7082078e-02 9.0000384e-02 1.2899015e-02] : 0.58536774
# 3 : [1.0754177e-03 8.1555342e-04 4.8292913e-03 9.6825790e-01 5.6801474e-04 2.4453811e-02] : 0.9682579
# 1 : [5.2922178e-06 9.9997115e-01 2.3567707e-05 8.5344432e-10 1.9027395e-12 4.2955905e-09] : 0.99997115
# 5 : [2.3227191e-02 6.4305395e-02 5.9865307e-02 4.5967898e-01 3.8864813e-04 3.9253449e-01] : 0.45967898
# 3 : [0.0272519  0.0134454  0.02093375 0.9019422  0.0052004  0.03122634] : 0.9019422
# 5 : [0.02098743 0.0110715  0.03146932 0.5254148  0.01190308 0.39915377] : 0.5254148
# 5 : [0.01033536 0.00172734 0.03966785 0.4680822  0.00650651 0.47368076] : 0.47368076
# 0 : [5.2922750e-01 4.0106943e-01 5.0492380e-02 1.8583780e-02 8.8875226e-05 5.3797674e-04] : 0.5292275
# 1 : [1.8107051e-02 8.9861000e-01 8.2755655e-02 4.8412773e-04 4.6136506e-07 4.2782896e-05] : 0.89861
# 3 : [0.01054914 0.0029674  0.0186508  0.7891915  0.00593625 0.17270496] : 0.7891915
# 5 : [0.83874595 0.00813338 0.10175696 0.01308472 0.00188098 0.03639804] : 0.83874595
# 5 : [0.0049873  0.00122979 0.00280934 0.22656761 0.00102343 0.7633825 ] : 0.7633825
# 1 : [2.1783276e-01 4.2401347e-01 3.4621626e-01 1.1088410e-02 2.5537662e-04 5.9378007e-04] : 0.42401347
# 2 : [7.5936723e-01 2.1162755e-03 2.3839967e-01 7.2584364e-05 1.0582139e-05 3.3707063e-05] : 0.7593672
# 5 : [0.0028658  0.00090112 0.00693637 0.5098201  0.0060103  0.47346628] : 0.5098201
# 4 : [6.1051861e-07 1.3364173e-07 9.5629003e-03 1.3082705e-02 9.7622311e-01 1.1305743e-03] : 0.9762231
# 0 : [9.7351372e-01 3.4279950e-05 2.4537135e-02 1.5728173e-03 1.1163134e-04 2.3043407e-04] : 0.9735137
# 1 : [1.8431713e-03 9.9463648e-01 3.4296566e-03 8.6865824e-05 1.5772853e-06 2.1416881e-06] : 0.9946365
# 4 : [3.1130479e-05 1.2130253e-05 1.0961514e-02 1.6205601e-01 8.2270777e-01 4.2314930e-03] : 0.8227078
# 0 : [7.7175647e-01 1.8056180e-01 3.8311519e-02 8.4959092e-03 9.5381300e-05 7.7890576e-04] : 0.7717565
